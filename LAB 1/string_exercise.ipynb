# %% [markdown]
# convert dollar amount to int
# check which is mutable list tuple dictionary check which changes address annd which doesn't
# copy data in list using (=, .copy(), [:]) and check which changes address of copied data wich doesn't

# %%
def remove_dollar(s):
    if(s.find('$') == 0):
        s = s.replace('$', '')
    return s

# %%
def remove_comma(s):
    s = s.replace(',', '')
    return int(s)

# %%
amount = [
    "$40,000",
    "$134",
    "$13,246",
    "$134,578,457",
    "$12"
]

def convert_to_int(s):
    s = remove_dollar(s)
    s = remove_comma(s)
    return s

for (i, entry) in enumerate(amount):
    entry = convert_to_int(entry)
    print(i,': ', entry)
    # print(type(entry))
# Out:
# 0 :  40000
# 1 :  134
# 2 :  13246
# 3 :  134578457
# 4 :  12

# %%
list = [1,2,3]
print(id(list))

list.append(5)
print(id(list))

#similar with dictionary
# Out:
# 1941366015936
# 1941366015936

# %%
t = (1,2,3)
print(id(t))

t = t + (5,)
print(id(t))
# Out:
# 1941365978560
# 1941366044480

# %%
# = points to same object
#.copy() creates new object
# [:] creates new list
# sort modifies inplace timsort
